# %% [markdown]
# # Example Notebook 2: Tension extraction

# %% [markdown]
# This notebook demonstrates how to extract tension from any given piece using the toolbox MusTen.

# %%
from __future__ import print_function

# %matplotlib inline

import librosa.display
import librosa
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
import seaborn as sns
from scipy.ndimage.filters import uniform_filter1d
from matplotlib.lines import Line2D


import dissonant
import os
import scipy
import pandas as pd

import import_ipynb
from scipy import stats
import spleeter

from pydub import AudioSegment
import soundfile
from scipy.signal import savgol_filter
from scipy import signal
import scipy.signal

from scipy.stats import spearmanr

# %% [markdown]
# ### Importing our custom functions

# %%
# %cd /Users/alice-vivien.barchet/claire_tension/MusTen/notebooks

import tension_functions_revised     #defining our custom functions
import Only_features_revised   #defining our custom functions
# Out:
# /Users/alice-vivien.barchet/claire_tension/MusTen/notebooks

# %% [markdown]
# ### 1. Importing and trimming the audio file
#
#
# This function will load the audio as well as cut away silence in the beginning and in the end. This trimmed version will be saved as a new audio file in the music directory.

# %%
file_name = "Mendelssohn"
inpath = "../music_files/"
outpath = "./music_trim/"
sr = 44100

y,sr,trimmed_audio_path = tension_functions_revised.music_loading(file_name, inpath, outpath, sr)
# Out:
# ../music_files/Mendelssohn.wav

# %% [markdown]
# ### 2. Extracting the features
#
# Here, we extract the features from our audio. For a more detailed view on the feature extraction, see example notebook 1.
#
# The features include:
# - Tempo
# - Loudness
# - Dissonance
# - Pitch Height
# - Onset frequency

# %%
df_all_features, df_plot = tension_functions_revised.feature_extraction(outpath, y, sr, file_name)
# Out:
# Estimating tempo...
# Estimating Onset frequency...
# Estimating loudness...
# [Info] A calibration of 1 Pa/FS is considered
# [Info] Signal resampled to 48 kHz to allow calculation.
# Estimating Pitch...
# Estimating polyphone pitch using Deep Salience
# Computing HCQT...
# 2023-08-08 14:44:16.806793: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Computing salience...
#    > 1 / 9
# 1/1 [==============================] - 12s 12s/step
#    > 2 / 9
# 1/1 [==============================] - 11s 11s/step
#    > 3 / 9
# 1/1 [==============================] - 17s 17s/step
#    > 4 / 9
# 1/1 [==============================] - 15s 15s/step
#    > 5 / 9
# 1/1 [==============================] - 12s 12s/step
#    > 6 / 9
# 1/1 [==============================] - 12s 12s/step
#    > 7 / 9
# 1/1 [==============================] - 11s 11s/step
#    > 8 / 9
# 1/1 [==============================] - 13s 13s/step
#    > 9 / 9
# 1/1 [==============================] - 10s 10s/step
# Saving output...
# /Users/alice-vivien.barchet/claire_tension/MusTen/notebooks/Only_features_revised.py:297: RuntimeWarning: Mean of empty slice
#   p_score = np.nanmean(ps)
# Estimating roughness...
# [Info] A calibration of 1 Pa/FS is considered
# [Info] Signal resampled to 48 kHz to allow calculation.
# 2023-08-08 14:51:29 PCX0033 __main__[58085] INFO key changed, change time is 1 minutes, 16 second
# 2023-08-08 14:51:29 PCX0033 __main__[58085] INFO new note shift is 5
# 2023-08-08 14:51:30 PCX0033 __main__[58085] INFO 1
# file name ./midi/Mendelssohn_trim_basic_pitch.mid, calculated key name D major
# if the calculated key name is not correct, you can set the key name by -n parameter

# %% [markdown]
# ### 3. Tension prediction
#
# Here, we will predict the tension from our features. Therefore, we will first smooth and resample the features and then submit them into the tension model.

# %%
#This function returns the smoothed and the unsmoothed features sampled at 10 Hz 
#We will use the smoothed features going further
df_features, features_unsmoothed = tension_functions_revised.feature_smoothing_resampling(df_all_features)

# %%
# %store -r df_features

# %% [markdown]
# Predicting the tension with the weighted prediction model using the our optimal weights.
#
# The tension prediction function returns:
# - One dataframe with our tension prediction and the time
# - One dataframe with the slopes for every feature
#
# We then compare the two model predictions with the feature slopes estimated by both model variants.

# %%
###Weighted model
tension_weights, feature_slopes = tension_functions_revised.tension_prediction(df_features, model_variant = "weight")

tension_functions_revised.plot_tension_and_features_10Hz(tension_weights, feature_slopes)

# %% [markdown]
# And extracting tension with the window model.

# %%
###Time Scale Model

tension_windows, feature_slopes = tension_functions_revised.tension_prediction(df_features, model_variant = "time_scale")

tension_functions_revised.plot_tension_and_features_10Hz(tension_windows, feature_slopes)

# %% [markdown]
# We see that the prediction from the weighted model follows the slopes for loudness slighlty more closely than the prediction from the time scale model.
# The slopes for tempo and dissonance loose some fluctuations in the time scale model, which is due to the long memory window sizes.

# %% [markdown]
# ### 4. Overlap with the Behavioral Tension Ratings
#
# Finally, we will assess the overlap with our behavioral tension ratings.

# %%
#Loading the behavioral data (standardized and sampled at 10 Hz)
dat_mendelssohn = pd.read_csv("../data_filter_new/Mendelssohn.csv")

dat_mendelssohn = dat_mendelssohn.fillna(0)
dat_mendelssohn['ratings_smooth'] = uniform_filter1d(dat_mendelssohn['mean_tension'], size =int(len(dat_mozart)/30)) 


dat_mendelssohn['time'] = pd.to_datetime(dat_mendelssohn['time'], errors='coerce')

dat_mendelssohn['time_dt'] = dat_mendelssohn['time']
dat_mendelssohn['diff'] = dat_mendelssohn['time_dt'] - pd.to_datetime(0, unit='s')
dat_mendelssohn['time'] = dat_mendelssohn['diff'].dt.total_seconds()

dat_mendelssohn = dat_mendelssohn.drop(columns = ['diff', 'time_dt'])

# %%
dat_mendelssohn['time']
# Out:
# 0         0.1
# 1         0.2
# 2         0.3
# 3         0.4
# 4         0.5
#         ...
# 1063    106.4
# 1064    106.5
# 1065    106.6
# 1066    106.7
# 1067    106.8
# Name: time, Length: 1068, dtype: float64

# %% [markdown]
# Now we plot the mean tension ratings as well as our tension predictions from both model configurations.

# %%
custom_lines = []
methods = ['Tension Ratings','Prediction Weights', 'Prediction Time Scale']

plt.figure(figsize = [20,6])
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20


piece = 'Mendelssohn'

###Ratings
plt.plot(dat_mendelssohn['time'], dat_mendelssohn['ratings_smooth'].shift(-45), color = "black", linewidth = 4)
custom_lines.append(Line2D([0], [0], color = 'black', lw = 5))


##Predictions
plt.plot(tension_weights['time'], tension_weights['tension_prediction'], color = sns.color_palette("Paired")[2], 
        linewidth = 5)
custom_lines.append(Line2D([0], [0], color = sns.color_palette("Paired")[2], lw = 5))
plt.plot(tension_windows['time'], tension_windows['tension_prediction'], color = sns.color_palette("Paired")[3], 
        linewidth = 5)
custom_lines.append(Line2D([0], [0], color = sns.color_palette("Paired")[3], lw = 5))


#Legend
plt.legend(custom_lines, methods , 
           loc='right', bbox_to_anchor=(1.267, 0.15), fancybox=True, facecolor='white', framealpha=1, 
          edgecolor = "black", fontsize = 20)


##Labels
plt.title("Tension Ratings and Model Predictions for Mozart", fontsize = 30)
plt.xlabel("Time (s)", fontsize = 20)
plt.ylabel("Z-Scores", fontsize = 20)
# Out:
# Text(0, 0.5, 'Z-Scores')

# %% [markdown]
# The correlations for all pieces as well as details on the procedure of the model optimization can be found in the publication.
